# %%
import json
import random
import sys
import zipfile
import copy
import re
import jieba
from collections import defaultdict
import os
import pickle as pkl

import numpy as np
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from pprint import pprint

# %%
from template_generate import TemplateNLG

# %%
archive = zipfile.ZipFile('data/test.json.zip', 'r')
test_data = json.load(archive.open('test.json'))

# %%
def split_delex_sentence(sen):
    res_sen = ''
    pattern = re.compile(r'(\[[^\[^\]]+\])')
    slots = pattern.findall(sen)
    for slot in slots:
        sen = sen.replace(slot, '[slot]')
    sen = sen.split('[slot]')
    for part in sen:
        part = ' '.join(jieba.lcut(part))
        res_sen += part
        if slots:
            res_sen += ' ' + slots.pop(0) + ' '
    return res_sen

# %%
def act2intent(dialog_act: list):
    cur_act = copy.deepcopy(dialog_act)
    # facility = None  # for 酒店设施
    if '酒店设施' in cur_act[2]:
        # facility = cur_act[2].split('-')[1]
        if cur_act[0] == 'Inform':
            cur_act[2] = cur_act[2].split('-')[0] + '+' + cur_act[3]
        elif cur_act[0] == 'Request':
            cur_act[2] = cur_act[2].split('-')[0]
    if cur_act[0] == 'Select':
        cur_act[2] = '源领域+' + cur_act[3]
    intent = '+'.join(cur_act[:-1])
    if '+'.join(cur_act) == 'Inform+景点+门票+免费':
        intent = '+'.join(cur_act)
    if cur_act[0] == 'Inform' and cur_act[-1] == '无':
#         intent = 'Inform+主体+属性+无'
        intent = '+'.join(cur_act)
    return intent

# %%
def value_replace(sentences, dialog_act):
    cur_sen = sentences
    dialog_act = copy.deepcopy(dialog_act)
    intent_frequency = defaultdict(int)
    for act in dialog_act:
        intent = act2intent(copy.deepcopy(act))
        intent_frequency[intent] += 1
        if intent_frequency[intent] > 1:  # if multiple same intents...
            intent += str(intent_frequency[intent])

        if '酒店设施' in intent:
            try:
                sentences = sentences.replace('[' + intent + ']', act[2].split('-')[1])
                sentences = sentences.replace('[' + intent + '1]', act[2].split('-')[1])
            except Exception as e:
                print('Act causing problem in replacement:')
                pprint(act)
                raise e
#         if act[0] == 'Inform' and act[3] == "无":
#             sentences = sentences.replace('[主体]', act[1])
#             sentences = sentences.replace('[属性]', act[2])
        else:
            sentences = sentences.replace('[' + intent + ']', act[3])
            sentences = sentences.replace('[' + intent + '1]', act[3])  # if multiple same intents and this is 1st

    if '[' in sentences and ']' in sentences:
        print('\n\nValue replacement not completed!!! Current sentence: %s' % sentences)
        print('current da:')
        print(dialog_act)
        print('original sen:')
        print(cur_sen)
        pattern = re.compile(r'(\[[^\[^\]]+\])')
        slots = pattern.findall(sentences)
        for slot in slots:
            sentences = sentences.replace(slot, ' ')
#         print('current da:')
#         print(dialog_act)
#         print('intent_frequency:')
#         print(intent_frequency)
#         raise Exception('\n\nValue replacement not completed!!! Current sentence: %s' % sentences)
    return sentences

# %%
def get_bleu4(dialog_acts, golden_utts, gen_utts, data_key):
    das2utts = {}
    for das, utt, gen in zip(dialog_acts, golden_utts, gen_utts):
        intent_frequency = defaultdict(int)
        for act in das:
            cur_act = copy.copy(act)

            # intent list
            facility = None  # for 酒店设施
            if '酒店设施' in cur_act[2]:
                facility = cur_act[2].split('-')[1]
                if cur_act[0] == 'Inform':
                    cur_act[2] = cur_act[2].split('-')[0] + '+' + cur_act[3]
                elif cur_act[0] == 'Request':
                    cur_act[2] = cur_act[2].split('-')[0]
            if cur_act[0] == 'Select':
                cur_act[2] = '源领域+' + cur_act[3]
            intent = '+'.join(cur_act[:-1])
            if '+'.join(cur_act) == 'Inform+景点+门票+免费':
                intent = '+'.join(cur_act)
            if cur_act[0] == 'Inform' and cur_act[-1] == '无':
#                 intent = 'Inform+主体+属性+无'
                intent = '+'.join(cur_act)

            intent_frequency[intent] += 1

            # utt content replacement
#             if act[0] == 'Inform' and '无' in intent:
#                 utt = utt.replace('+' + act[1] + '+', '+' + '&'.join(act[1]) + '+')
#                 utt = utt.replace('+' + act[2] + '+', '+' + '&'.join(act[2]) + '+')
#                 utt = utt.replace(act[1], '[主体]')
#                 utt = utt.replace(act[2], '[属性]')
#                 utt = utt.replace('&', '')
#                 gen = gen.replace('+' + act[1] + '+', '+' + '&'.join(act[1]) + '+')
#                 gen = gen.replace('+' + act[2] + '+', '+' + '&'.join(act[2]) + '+')
#                 gen = gen.replace(act[1], '[主体]')
#                 gen = gen.replace(act[2], '[属性]')
#                 gen = gen.replace('&', '')
            if (act[0] in ['Inform', 'Recommend'] or '酒店设施' in intent) and '无' not in intent:
                if act[3] in utt or (facility and facility in utt):
                    # value to be replaced
                    if '酒店设施' in intent:
                        value = facility
                    else:
                        value = act[3]

                    # placeholder
                    placeholder = '[' + intent + ']'
                    placeholder_one = '[' + intent + '1]'
                    placeholder_with_number = '[' + intent + str(intent_frequency[intent]) + ']'

                    if intent_frequency[intent] > 1:
                        utt = utt.replace(placeholder, placeholder_one)
                        utt = utt.replace(value, placeholder_with_number)
                        
                        gen = gen.replace(placeholder, placeholder_one)
                        gen = gen.replace(value, placeholder_with_number)
                    else:
                        utt = utt.replace(value, placeholder)
                        gen = gen.replace(value, placeholder)

        hash_key = ''
        for act in sorted(das):
            hash_key += act2intent(act)
        das2utts.setdefault(hash_key, {'refs': [], 'gens': []})
        das2utts[hash_key]['refs'].append(utt)
#         das2utts[hash_key]['gens'].append(gen)  # todo here template only generate one 'gen'
        das2utts[hash_key]['gens'].append({
            'das': das,
            'gen': gen
        })
#         print(utt, gen)
#     pprint(das2utts)
    refs, gens = [], []
    for das in das2utts.keys():
        # print('refs:')
        # print(len(das2utts[das]['refs']))
        # print('gens:')
        # print(len(das2utts[das]['gens']))
        assert len(das2utts[das]['refs']) == (len(das2utts[das]['gens']))
#         for gen in das2utts[das]['gens']:
#             # refs.append([s.split() for s in das2utts[das]['refs']])
#             refs.append([split_delex_sentence(s) for s in das2utts[das]['refs']])
#             gens.append(split_delex_sentence(gen))
        for gen_pair in das2utts[das]['gens']:
                lex_das = gen_pair['das']  # das w/ value
                gen = gen_pair['gen']
                lex_gen = value_replace(gen, lex_das)
#                 gens.append(' '.join(jieba.lcut(lex_gen)))
#                 refs.append([' '.join(jieba.lcut(value_replace(s, lex_das))) for s in das2utts[das]['refs']])
                gens.append([x for x in jieba.lcut(lex_gen) if x.strip()])
                refs.append([[x for x in jieba.lcut(value_replace(s, lex_das)) if x.strip()] for s in das2utts[das]['refs']])
                
    print('Start calculating bleu score...')
    from pprint import pprint
    print('refs:')
    pprint(refs[:10])
    print('gens:')
    pprint(gens[:10])
    with open(os.path.join('', 'generated_sens_%s.json' % data_key), 'w', encoding='utf-8') as f:
        json.dump({'refs': refs, 'gens': gens}, f, indent=4, sort_keys=True, ensure_ascii=False)
    print('generated_sens_%s.txt saved!' % data_key)
    bleu = corpus_bleu(refs, gens, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=SmoothingFunction().method1)
    return bleu

# %%
for data_key in ['sys', 'usr']:
    print('data_key: ', data_key)
    
    dialog_acts = []
    golden_utts = []
    gen_utts = []
    gen_slots = []
    intent_list = []
    dialog_acts2genutts = defaultdict(list)

    sen_num = 0
    sess_num = 0

    if os.path.isfile('dialog_acts_%s.pkl' % data_key) and os.path.isfile('golden_utts_%s.pkl' % data_key) and os.path.isfile('gen_utts_%s.pkl' % data_key):
        with open('dialog_acts_%s.pkl' % data_key, 'rb') as fda:
            dialog_acts = pkl.load(fda)
        with open('golden_utts_%s.pkl' % data_key, 'rb') as fgold:
            golden_utts = pkl.load(fgold)
        with open('gen_utts_%s.pkl' % data_key, 'rb') as fgen:
            gen_utts = pkl.load(fgen)
        for no, sess in list(test_data.items()):
            sess_num += 1
#             print('[%d/%d]' % (sess_num, len(test_data)))
            for turn in sess['messages']:
                if turn['role'] == 'usr' and data_key == 'sys':
                    continue
                elif turn['role'] == 'sys' and data_key == 'usr':
                    continue
                sen_num += 1
        print('sen_num: ', sen_num)
    else:
        for no, sess in list(test_data.items()):
            sess_num += 1
            print('[%d/%d]' % (sess_num, len(test_data)))
            for turn in sess['messages']:
                if turn['role'] == 'usr' and data_key == 'sys':
                    continue
                elif turn['role'] == 'sys' and data_key == 'usr':
                    continue
                sen_num += 1

                template_nlg = TemplateNLG(is_user=data_key == 'usr', mode='auto_manual')

                dialog_acts.append(turn['dialog_act'])
                golden_utts.append(turn['content'])  # slots **values**
                # gen_utts.append(model.generate(turn['dialog_act']))

                gen_utts.append(template_nlg.generate(turn['dialog_act']))  # slots **values**
                
#                 intent_list = []
#                 for act in turn['dialog_act']:
#                     intent_list.append(act2intent(act))
#                 dialog_acts2genutts['*'.join(intent_list)].append(gen_utt)
#                 dialog_acts2goldutts['*'.join(intent_list)].append(turn['content'])

#             if sess_num % 10 == 0:
#                 with open(os.path.join('', 'generated_sens_%s.json' % data_key), 'w', encoding='utf-8') as f:
#                     json.dump(dialog_acts2genutts, f, indent=4, sort_keys=True, ensure_ascii=False)
#                 print('generated_sens_%s.txt saved at iteration #{}!'.format(data_key.format(sess_num)))
#                 with open(os.path.join('', 'golden_sens_%s.json' % data_key), 'w', encoding='utf-8') as f:
#                     json.dump(dialog_acts2genutts, f, indent=4, sort_keys=True, ensure_ascii=False)
#                 print('golden_sens_%s.txt saved at iteration #{}!'.format(data_key.format(sess_num)))
                
        with open('dialog_acts_%s.pkl' % data_key, 'wb') as fda:
            pkl.dump(dialog_acts, fda)
        with open('golden_utts_%s.pkl' % data_key, 'wb') as fgold:
            pkl.dump(golden_utts, fgold)
        with open('gen_utts_%s.pkl' % data_key, 'wb') as fgen:
            pkl.dump(gen_utts, fgen)

    bleu4 = get_bleu4(dialog_acts, golden_utts, gen_utts, data_key)
    print("Calculate bleu-4")
    print("BLEU-4: %.4f" % bleu4)
    print("BLEU-4: %.4f" % bleu4)
    print('Model on {} session {} sentences data_key={}'.format(len(test_data), sen_num, data_key))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/ht/8jl6l88n1_v610_t1jz69s440000gn/T/jieba.cache
# data_key:  sys
# sen_num:  4238
# Loading model cost 0.696 seconds.
# Prefix dict has been built succesfully.
# Value replacement not completed!!! Current sentence: 电话是人均消费，人均消费是[Inform+餐馆+人均消费]。
# current da:
# [['Inform', '餐馆', '人均消费', '74元'], ['Inform', '餐馆', '电话', '人均消费']]
# original sen:
# 电话是[Inform+餐馆+电话]，[Inform+餐馆+电话]是[Inform+餐馆+[Inform+餐馆+电话]]。
#
#
# Value replacement not completed!!! Current sentence: 电话是010-59683511，人均消费为[Inform+餐馆+人均消费]。
# current da:
# [['Inform', '餐馆', '人均消费', '74元'], ['Inform', '餐馆', '电话', '人均消费']]
# original sen:
# 电话是010-59683511，[Inform+餐馆+电话]为[Inform+餐馆+[Inform+餐馆+电话]]。
# Start calculating bleu score...
# refs:
# [[['为',
#    '您',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '有',
#    '您',
#    '想',
#    '吃',
#    '的',
#    '美食街',
#    '哦',
#    '。'],
#   ['推荐',
#    '您',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['我',
#    '推荐',
#    '你',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '尝尝',
#    '，',
#    '他家',
#    '做',
#    '的',
#    '很',
#    '好吃',
#    '，',
#    '不过',
#    '就是',
#    '价格',
#    '有点',
#    '高',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '，',
#    '你',
#    '能',
#    '接受',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['没有',
#    '人均',
#    '这么',
#    '高',
#    '的',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '人均',
#    '只有',
#    '75',
#    '元',
#    '。'],
#   ['吃',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '的',
#    '餐馆',
#    '没有',
#    '那么',
#    '贵',
#    '的',
#    '哟',
#    '，',
#    '推荐',
#    '你',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '价格',
#    '才',
#    '75',
#    '元',
#    '，',
#    '而且',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '做',
#    '的',
#    '也',
#    '非常',
#    '好吃',
#    '。'],
#   ['只为',
#    '您',
#    '找到',
#    '一家',
#    '店',
#    '是',
#    '\t',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['我',
#    '只查',
#    '到',
#    '一家',
#    '，',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '可以',
#    '做',
#    '，',
#    '但',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '，',
#    '你',
#    '还要',
#    '不要',
#    '去',
#    '吃',
#    '呢',
#    '？'],
#   ['那',
#    '我',
#    '推荐',
#    '您',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '此',
#    '餐馆',
#    '正好',
#    '有',
#    '您',
#    '要',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '比',
#    '您',
#    '要求',
#    '的',
#    '标准',
#    '能',
#    '高',
#    '一点',
#    '，',
#    '但',
#    '我',
#    '觉得',
#    '此',
#    '价位',
#    '应该',
#    '能',
#    '接受',
#    '。'],
#   ['为',
#    '您',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '暂无',
#    '评分',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '里面',
#    '有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '特色菜',
#    '哦',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '！'],
#   ['鲜鱼', '口', '老字号', '美食街', '挺好吃', '的', '，', '人均', '消费', '75', '元', '。'],
#   ['餐馆',
#    '周边',
#    '可',
#    '没有',
#    '这么',
#    '高价位',
#    '的',
#    '地方',
#    '，',
#    '人均',
#    '消费',
#    '最贵',
#    '的',
#    '当属',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '了',
#    '，',
#    '也',
#    '才',
#    '不过',
#    '75',
#    '元',
#    '，',
#    '看',
#    '你',
#    '能',
#    '接受',
#    '不',
#    '？'],
#   ['很',
#    '抱歉',
#    '，',
#    '有',
#    '这些',
#    '推荐',
#    '菜',
#    '的',
#    '餐馆',
#    '我',
#    '只查',
#    '到',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '但',
#    '这里',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '没有',
#    '评分',
#    '，',
#    '你',
#    '还',
#    '会',
#    '考虑',
#    '吗',
#    '？'],
#   ['抱歉',
#    '，',
#    '没有',
#    '这样',
#    '的',
#    '餐馆',
#    '。',
#    '给',
#    '您',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '很',
#    '不错',
#    '呢',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '您',
#    '可以',
#    '考虑',
#    '下',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['没关系',
#    '，',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '，',
#    '还是',
#    '比较',
#    '符合',
#    '你',
#    '要求',
#    '的',
#    '。'],
#   ['建议',
#    '你们',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['那',
#    '就',
#    '推荐',
#    '您',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['亲',
#    '，',
#    '要',
#    '不',
#    '您',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '吧',
#    '，',
#    '但是',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '，',
#    '您',
#    '看',
#    '怎么样',
#    '？'],
#   ['没有',
#    '合适',
#    '的',
#    '哦',
#    '，',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '有',
#    '蛋炒饭',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['我查',
#    '了',
#    '一家',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '的',
#    '，',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '，',
#    '你',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '推荐',
#    '菜里',
#    '有',
#    '油麦',
#    '菜',
#    '。'],
#   ['这边',
#    '向',
#    '您',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '虽然',
#    '价格比',
#    '您',
#    '期望值',
#    '高',
#    '了',
#    '一点',
#    '，',
#    '但是',
#    '味道',
#    '真的',
#    '是',
#    '很',
#    '好',
#    '的',
#    '。'],
#   ['都',
#    '没有',
#    '，',
#    '但',
#    '我',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '更',
#    '低',
#    '，',
#    '为',
#    '75',
#    '元',
#    '。'],
#   ['推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '有',
#    '精品',
#    '烤鸭',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '。'],
#   ['为',
#    '你',
#    '推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '。'],
#   ['没有',
#    '啊',
#    '，',
#    '这',
#    '两',
#    '几点',
#    '的',
#    '消费',
#    '都',
#    '比较',
#    '高',
#    '，',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '消费',
#    '稍微',
#    '低',
#    '一点',
#    '，',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['当然',
#    '可以',
#    '，',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '就',
#    '不错',
#    '，',
#    '但',
#    '人均',
#    '消费',
#    '要',
#    '75',
#    '元',
#    '。'],
#   ['按',
#    '您',
#    '的',
#    '推荐',
#    '菜',
#    '查询',
#    '，',
#    '只有',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '符合',
#    '您',
#    '的',
#    '要求',
#    '，',
#    '但',
#    '它',
#    '的',
#    '评分',
#    '是',
#    '4',
#    '分',
#    '，',
#    '然后',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['推荐',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '。'],
#   ['建议您',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '品尝',
#    '一下',
#    '，',
#    '这家',
#    '店',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。',
#    '这家',
#    '餐馆',
#    '有',
#    '很多',
#    '特色',
#    '北京小吃',
#    '，',
#    '能',
#    '让',
#    '您',
#    '一站',
#    '就',
#    '吃',
#    '个',
#    '遍',
#    '！'],
#   ['鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '有',
#    '您',
#    '要',
#    '吃',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '只',
#    '需要',
#    '75',
#    '元',
#    '。'],
#   ['鲜鱼', '口', '老字号', '美食街', '，', '人均', '消费', '在', '75', '元', '。'],
#   ['推荐',
#    '你',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '消费',
#    '没有',
#    '那么',
#    '高',
#    '，',
#    '人均',
#    '才',
#    '75',
#    '元',
#    '，',
#    '味道',
#    '不错',
#    '。'],
#   ['它',
#    '周边',
#    '无',
#    '餐馆',
#    '，',
#    '如果',
#    '您',
#    '以',
#    '菜品',
#    '为主',
#    '的话',
#    '，',
#    '我',
#    '推荐',
#    '您',
#    '别的',
#    '地方',
#    '的',
#    '餐馆',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '。'],
#   ['鲜鱼', '口', '老字号', '美食街', '怎么样', '，', '人均', '消费', '是', '75', '元', '。'],
#   ['你',
#    '看',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '可以',
#    '吗',
#    '？',
#    '有',
#    '蘑菇',
#    '包',
#    '和',
#    '牛排',
#    '，',
#    '就是',
#    '价格',
#    '稍稍',
#    '贵',
#    '了',
#    '一点',
#    '，',
#    '75',
#    '元',
#    '。'],
#   ['鲜鱼', '口', '老字号', '美食街', '不错', '，', '人均', '消费', '是', '75', '元', '。'],
#   ['没有',
#    '消费',
#    '这么',
#    '高',
#    '的',
#    '餐馆',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '才',
#    '75',
#    '元',
#    '。'],
#   ['鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '不错',
#    '，',
#    '好吃',
#    '还',
#    '便宜',
#    '，',
#    '人均',
#    '75',
#    '元',
#    '。'],
#   ['在',
#    '我',
#    '的',
#    '查询',
#    '后',
#    '，',
#    '鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '这家',
#    '店有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '泡',
#    '菜汤',
#    '，',
#    '但是',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '75',
#    '元',
#    '，',
#    '低于',
#    '您',
#    '的',
#    '人均',
#    '消费',
#    '水准',
#    '。'],
#   ['鲜鱼', '口', '老字号', '美食街', '就', '不错', '，', '人均', '消费', '75', '元', '。'],
#   ['鲜鱼',
#    '口',
#    '老字号',
#    '美食街',
#    '人均',
#    '消费',
#    '75',
#    '元',
#    '，',
#    '您',
#    '可以',
#    '去',
#    '试试',
#    '呢',
#    '。']],
#  [['为',
#    '您',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '有',
#    '您',
#    '想',
#    '吃',
#    '的',
#    '美食街',
#    '哦',
#    '。'],
#   ['推荐',
#    '您',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['我',
#    '推荐',
#    '你',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '尝尝',
#    '，',
#    '他家',
#    '做',
#    '的',
#    '很',
#    '好吃',
#    '，',
#    '不过',
#    '就是',
#    '价格',
#    '有点',
#    '高',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '，',
#    '你',
#    '能',
#    '接受',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['没有',
#    '人均',
#    '这么',
#    '高',
#    '的',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '只有',
#    '68',
#    '元',
#    '。'],
#   ['吃',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '的',
#    '餐馆',
#    '没有',
#    '那么',
#    '贵',
#    '的',
#    '哟',
#    '，',
#    '推荐',
#    '你',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '价格',
#    '才',
#    '68',
#    '元',
#    '，',
#    '而且',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '做',
#    '的',
#    '也',
#    '非常',
#    '好吃',
#    '。'],
#   ['只为',
#    '您',
#    '找到',
#    '一家',
#    '店',
#    '是',
#    '\t',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['我',
#    '只查',
#    '到',
#    '一家',
#    '，',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '可以',
#    '做',
#    '，',
#    '但',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '，',
#    '你',
#    '还要',
#    '不要',
#    '去',
#    '吃',
#    '呢',
#    '？'],
#   ['那',
#    '我',
#    '推荐',
#    '您',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '此',
#    '餐馆',
#    '正好',
#    '有',
#    '您',
#    '要',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '比',
#    '您',
#    '要求',
#    '的',
#    '标准',
#    '能',
#    '高',
#    '一点',
#    '，',
#    '但',
#    '我',
#    '觉得',
#    '此',
#    '价位',
#    '应该',
#    '能',
#    '接受',
#    '。'],
#   ['为',
#    '您',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '暂无',
#    '评分',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '里面',
#    '有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '特色菜',
#    '哦',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '！'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '挺好吃',
#    '的',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '。'],
#   ['餐馆',
#    '周边',
#    '可',
#    '没有',
#    '这么',
#    '高价位',
#    '的',
#    '地方',
#    '，',
#    '人均',
#    '消费',
#    '最贵',
#    '的',
#    '当属',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '了',
#    '，',
#    '也',
#    '才',
#    '不过',
#    '68',
#    '元',
#    '，',
#    '看',
#    '你',
#    '能',
#    '接受',
#    '不',
#    '？'],
#   ['很',
#    '抱歉',
#    '，',
#    '有',
#    '这些',
#    '推荐',
#    '菜',
#    '的',
#    '餐馆',
#    '我',
#    '只查',
#    '到',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '但',
#    '这里',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '没有',
#    '评分',
#    '，',
#    '你',
#    '还',
#    '会',
#    '考虑',
#    '吗',
#    '？'],
#   ['抱歉',
#    '，',
#    '没有',
#    '这样',
#    '的',
#    '餐馆',
#    '。',
#    '给',
#    '您',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '很',
#    '不错',
#    '呢',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '您',
#    '可以',
#    '考虑',
#    '下',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['没关系',
#    '，',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '，',
#    '还是',
#    '比较',
#    '符合',
#    '你',
#    '要求',
#    '的',
#    '。'],
#   ['建议',
#    '你们',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['那',
#    '就',
#    '推荐',
#    '您',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['亲',
#    '，',
#    '要',
#    '不',
#    '您',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '但是',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '，',
#    '您',
#    '看',
#    '怎么样',
#    '？'],
#   ['没有',
#    '合适',
#    '的',
#    '哦',
#    '，',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '有',
#    '蛋炒饭',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['我查',
#    '了',
#    '一家',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '的',
#    '，',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '，',
#    '你',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '推荐',
#    '菜里',
#    '有',
#    '油麦',
#    '菜',
#    '。'],
#   ['这边',
#    '向',
#    '您',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '虽然',
#    '价格比',
#    '您',
#    '期望值',
#    '高',
#    '了',
#    '一点',
#    '，',
#    '但是',
#    '味道',
#    '真的',
#    '是',
#    '很',
#    '好',
#    '的',
#    '。'],
#   ['都',
#    '没有',
#    '，',
#    '但',
#    '我',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '更',
#    '低',
#    '，',
#    '为',
#    '68',
#    '元',
#    '。'],
#   ['推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '有',
#    '精品',
#    '烤鸭',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '。'],
#   ['为',
#    '你',
#    '推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '。'],
#   ['没有',
#    '啊',
#    '，',
#    '这',
#    '两',
#    '几点',
#    '的',
#    '消费',
#    '都',
#    '比较',
#    '高',
#    '，',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '消费',
#    '稍微',
#    '低',
#    '一点',
#    '，',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['当然',
#    '可以',
#    '，',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '就',
#    '不错',
#    '，',
#    '但',
#    '人均',
#    '消费',
#    '要',
#    '68',
#    '元',
#    '。'],
#   ['按',
#    '您',
#    '的',
#    '推荐',
#    '菜',
#    '查询',
#    '，',
#    '只有',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '符合',
#    '您',
#    '的',
#    '要求',
#    '，',
#    '但',
#    '它',
#    '的',
#    '评分',
#    '是',
#    '4',
#    '分',
#    '，',
#    '然后',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['推荐',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '。'],
#   ['建议您',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '品尝',
#    '一下',
#    '，',
#    '这家',
#    '店',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。',
#    '这家',
#    '餐馆',
#    '有',
#    '很多',
#    '特色',
#    '北京小吃',
#    '，',
#    '能',
#    '让',
#    '您',
#    '一站',
#    '就',
#    '吃',
#    '个',
#    '遍',
#    '！'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '有',
#    '您',
#    '要',
#    '吃',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '只',
#    '需要',
#    '68',
#    '元',
#    '。'],
#   ['铁木真', '(', '温都', '水城', '店', ')', '，', '人均', '消费', '在', '68', '元', '。'],
#   ['推荐',
#    '你',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '消费',
#    '没有',
#    '那么',
#    '高',
#    '，',
#    '人均',
#    '才',
#    '68',
#    '元',
#    '，',
#    '味道',
#    '不错',
#    '。'],
#   ['它',
#    '周边',
#    '无',
#    '餐馆',
#    '，',
#    '如果',
#    '您',
#    '以',
#    '菜品',
#    '为主',
#    '的话',
#    '，',
#    '我',
#    '推荐',
#    '您',
#    '别的',
#    '地方',
#    '的',
#    '餐馆',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '怎么样',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['你',
#    '看',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '可以',
#    '吗',
#    '？',
#    '有',
#    '蘑菇',
#    '包',
#    '和',
#    '牛排',
#    '，',
#    '就是',
#    '价格',
#    '稍稍',
#    '贵',
#    '了',
#    '一点',
#    '，',
#    '68',
#    '元',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '不错',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '。'],
#   ['没有',
#    '消费',
#    '这么',
#    '高',
#    '的',
#    '餐馆',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '才',
#    '68',
#    '元',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '不错',
#    '，',
#    '好吃',
#    '还',
#    '便宜',
#    '，',
#    '人均',
#    '68',
#    '元',
#    '。'],
#   ['在',
#    '我',
#    '的',
#    '查询',
#    '后',
#    '，',
#    '铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '这家',
#    '店有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '泡',
#    '菜汤',
#    '，',
#    '但是',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '68',
#    '元',
#    '，',
#    '低于',
#    '您',
#    '的',
#    '人均',
#    '消费',
#    '水准',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '就',
#    '不错',
#    '，',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '。'],
#   ['铁木真',
#    '(',
#    '温都',
#    '水城',
#    '店',
#    ')',
#    '人均',
#    '消费',
#    '68',
#    '元',
#    '，',
#    '您',
#    '可以',
#    '去',
#    '试试',
#    '呢',
#    '。']],
#  [['为',
#    '您',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '有',
#    '您',
#    '想',
#    '吃',
#    '的',
#    '美食街',
#    '哦',
#    '。'],
#   ['推荐',
#    '您',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['我',
#    '推荐',
#    '你',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '尝尝',
#    '，',
#    '他家',
#    '做',
#    '的',
#    '很',
#    '好吃',
#    '，',
#    '不过',
#    '就是',
#    '价格',
#    '有点',
#    '高',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '，',
#    '你',
#    '能',
#    '接受',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['没有',
#    '人均',
#    '这么',
#    '高',
#    '的',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '只有',
#    '143',
#    '元',
#    '。'],
#   ['吃',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '的',
#    '餐馆',
#    '没有',
#    '那么',
#    '贵',
#    '的',
#    '哟',
#    '，',
#    '推荐',
#    '你',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '价格',
#    '才',
#    '143',
#    '元',
#    '，',
#    '而且',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '做',
#    '的',
#    '也',
#    '非常',
#    '好吃',
#    '。'],
#   ['只为',
#    '您',
#    '找到',
#    '一家',
#    '店',
#    '是',
#    '\t',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['我',
#    '只查',
#    '到',
#    '一家',
#    '，',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '可以',
#    '做',
#    '，',
#    '但',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '，',
#    '你',
#    '还要',
#    '不要',
#    '去',
#    '吃',
#    '呢',
#    '？'],
#   ['那',
#    '我',
#    '推荐',
#    '您',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '此',
#    '餐馆',
#    '正好',
#    '有',
#    '您',
#    '要',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '比',
#    '您',
#    '要求',
#    '的',
#    '标准',
#    '能',
#    '高',
#    '一点',
#    '，',
#    '但',
#    '我',
#    '觉得',
#    '此',
#    '价位',
#    '应该',
#    '能',
#    '接受',
#    '。'],
#   ['为',
#    '您',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '暂无',
#    '评分',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '里面',
#    '有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '特色菜',
#    '哦',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '！'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '挺好吃',
#    '的',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '。'],
#   ['餐馆',
#    '周边',
#    '可',
#    '没有',
#    '这么',
#    '高价位',
#    '的',
#    '地方',
#    '，',
#    '人均',
#    '消费',
#    '最贵',
#    '的',
#    '当属',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '了',
#    '，',
#    '也',
#    '才',
#    '不过',
#    '143',
#    '元',
#    '，',
#    '看',
#    '你',
#    '能',
#    '接受',
#    '不',
#    '？'],
#   ['很',
#    '抱歉',
#    '，',
#    '有',
#    '这些',
#    '推荐',
#    '菜',
#    '的',
#    '餐馆',
#    '我',
#    '只查',
#    '到',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '但',
#    '这里',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '没有',
#    '评分',
#    '，',
#    '你',
#    '还',
#    '会',
#    '考虑',
#    '吗',
#    '？'],
#   ['抱歉',
#    '，',
#    '没有',
#    '这样',
#    '的',
#    '餐馆',
#    '。',
#    '给',
#    '您',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '很',
#    '不错',
#    '呢',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '您',
#    '可以',
#    '考虑',
#    '下',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['没关系',
#    '，',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '，',
#    '还是',
#    '比较',
#    '符合',
#    '你',
#    '要求',
#    '的',
#    '。'],
#   ['建议',
#    '你们',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['那',
#    '就',
#    '推荐',
#    '您',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['亲',
#    '，',
#    '要',
#    '不',
#    '您',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '但是',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '，',
#    '您',
#    '看',
#    '怎么样',
#    '？'],
#   ['没有',
#    '合适',
#    '的',
#    '哦',
#    '，',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '有',
#    '蛋炒饭',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['我查',
#    '了',
#    '一家',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '的',
#    '，',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '，',
#    '你',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '推荐',
#    '菜里',
#    '有',
#    '油麦',
#    '菜',
#    '。'],
#   ['这边',
#    '向',
#    '您',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '虽然',
#    '价格比',
#    '您',
#    '期望值',
#    '高',
#    '了',
#    '一点',
#    '，',
#    '但是',
#    '味道',
#    '真的',
#    '是',
#    '很',
#    '好',
#    '的',
#    '。'],
#   ['都',
#    '没有',
#    '，',
#    '但',
#    '我',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '更',
#    '低',
#    '，',
#    '为',
#    '143',
#    '元',
#    '。'],
#   ['推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '有',
#    '精品',
#    '烤鸭',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '。'],
#   ['为',
#    '你',
#    '推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '。'],
#   ['没有',
#    '啊',
#    '，',
#    '这',
#    '两',
#    '几点',
#    '的',
#    '消费',
#    '都',
#    '比较',
#    '高',
#    '，',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '消费',
#    '稍微',
#    '低',
#    '一点',
#    '，',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['当然',
#    '可以',
#    '，',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '就',
#    '不错',
#    '，',
#    '但',
#    '人均',
#    '消费',
#    '要',
#    '143',
#    '元',
#    '。'],
#   ['按',
#    '您',
#    '的',
#    '推荐',
#    '菜',
#    '查询',
#    '，',
#    '只有',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '符合',
#    '您',
#    '的',
#    '要求',
#    '，',
#    '但',
#    '它',
#    '的',
#    '评分',
#    '是',
#    '4',
#    '分',
#    '，',
#    '然后',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['推荐',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '。'],
#   ['建议您',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '品尝',
#    '一下',
#    '，',
#    '这家',
#    '店',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。',
#    '这家',
#    '餐馆',
#    '有',
#    '很多',
#    '特色',
#    '北京小吃',
#    '，',
#    '能',
#    '让',
#    '您',
#    '一站',
#    '就',
#    '吃',
#    '个',
#    '遍',
#    '！'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '有',
#    '您',
#    '要',
#    '吃',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '只',
#    '需要',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '在',
#    '143',
#    '元',
#    '。'],
#   ['推荐',
#    '你',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '消费',
#    '没有',
#    '那么',
#    '高',
#    '，',
#    '人均',
#    '才',
#    '143',
#    '元',
#    '，',
#    '味道',
#    '不错',
#    '。'],
#   ['它',
#    '周边',
#    '无',
#    '餐馆',
#    '，',
#    '如果',
#    '您',
#    '以',
#    '菜品',
#    '为主',
#    '的话',
#    '，',
#    '我',
#    '推荐',
#    '您',
#    '别的',
#    '地方',
#    '的',
#    '餐馆',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '怎么样',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['你',
#    '看',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '可以',
#    '吗',
#    '？',
#    '有',
#    '蘑菇',
#    '包',
#    '和',
#    '牛排',
#    '，',
#    '就是',
#    '价格',
#    '稍稍',
#    '贵',
#    '了',
#    '一点',
#    '，',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '不错',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '。'],
#   ['没有',
#    '消费',
#    '这么',
#    '高',
#    '的',
#    '餐馆',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '才',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '不错',
#    '，',
#    '好吃',
#    '还',
#    '便宜',
#    '，',
#    '人均',
#    '143',
#    '元',
#    '。'],
#   ['在',
#    '我',
#    '的',
#    '查询',
#    '后',
#    '，',
#    '便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '这家',
#    '店有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '泡',
#    '菜汤',
#    '，',
#    '但是',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '143',
#    '元',
#    '，',
#    '低于',
#    '您',
#    '的',
#    '人均',
#    '消费',
#    '水准',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '就',
#    '不错',
#    '，',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '。'],
#   ['便宜',
#    '坊',
#    '烤鸭店',
#    '(',
#    '哈德门',
#    '店',
#    ')',
#    '人均',
#    '消费',
#    '143',
#    '元',
#    '，',
#    '您',
#    '可以',
#    '去',
#    '试试',
#    '呢',
#    '。']],
#  [['为',
#    '您',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '有',
#    '您',
#    '想',
#    '吃',
#    '的',
#    '美食街',
#    '哦',
#    '。'],
#   ['推荐',
#    '您',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['我',
#    '推荐',
#    '你',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '尝尝',
#    '，',
#    '他家',
#    '做',
#    '的',
#    '很',
#    '好吃',
#    '，',
#    '不过',
#    '就是',
#    '价格',
#    '有点',
#    '高',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '，',
#    '你',
#    '能',
#    '接受',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['没有',
#    '人均',
#    '这么',
#    '高',
#    '的',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '只有',
#    '171',
#    '元',
#    '。'],
#   ['吃',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '的',
#    '餐馆',
#    '没有',
#    '那么',
#    '贵',
#    '的',
#    '哟',
#    '，',
#    '推荐',
#    '你',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '价格',
#    '才',
#    '171',
#    '元',
#    '，',
#    '而且',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '做',
#    '的',
#    '也',
#    '非常',
#    '好吃',
#    '。'],
#   ['只为',
#    '您',
#    '找到',
#    '一家',
#    '店',
#    '是',
#    '\t',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['我',
#    '只查',
#    '到',
#    '一家',
#    '，',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '可以',
#    '做',
#    '，',
#    '但',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '，',
#    '你',
#    '还要',
#    '不要',
#    '去',
#    '吃',
#    '呢',
#    '？'],
#   ['那',
#    '我',
#    '推荐',
#    '您',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '此',
#    '餐馆',
#    '正好',
#    '有',
#    '您',
#    '要',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '比',
#    '您',
#    '要求',
#    '的',
#    '标准',
#    '能',
#    '高',
#    '一点',
#    '，',
#    '但',
#    '我',
#    '觉得',
#    '此',
#    '价位',
#    '应该',
#    '能',
#    '接受',
#    '。'],
#   ['为',
#    '您',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '暂无',
#    '评分',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '里面',
#    '有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '特色菜',
#    '哦',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '！'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '挺好吃',
#    '的',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '。'],
#   ['餐馆',
#    '周边',
#    '可',
#    '没有',
#    '这么',
#    '高价位',
#    '的',
#    '地方',
#    '，',
#    '人均',
#    '消费',
#    '最贵',
#    '的',
#    '当属',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '了',
#    '，',
#    '也',
#    '才',
#    '不过',
#    '171',
#    '元',
#    '，',
#    '看',
#    '你',
#    '能',
#    '接受',
#    '不',
#    '？'],
#   ['很',
#    '抱歉',
#    '，',
#    '有',
#    '这些',
#    '推荐',
#    '菜',
#    '的',
#    '餐馆',
#    '我',
#    '只查',
#    '到',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '但',
#    '这里',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '没有',
#    '评分',
#    '，',
#    '你',
#    '还',
#    '会',
#    '考虑',
#    '吗',
#    '？'],
#   ['抱歉',
#    '，',
#    '没有',
#    '这样',
#    '的',
#    '餐馆',
#    '。',
#    '给',
#    '您',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '很',
#    '不错',
#    '呢',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '您',
#    '可以',
#    '考虑',
#    '下',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['没关系',
#    '，',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '，',
#    '还是',
#    '比较',
#    '符合',
#    '你',
#    '要求',
#    '的',
#    '。'],
#   ['建议',
#    '你们',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['那',
#    '就',
#    '推荐',
#    '您',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['亲',
#    '，',
#    '要',
#    '不',
#    '您',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '但是',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '，',
#    '您',
#    '看',
#    '怎么样',
#    '？'],
#   ['没有',
#    '合适',
#    '的',
#    '哦',
#    '，',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '有',
#    '蛋炒饭',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['我查',
#    '了',
#    '一家',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '的',
#    '，',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '，',
#    '你',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '推荐',
#    '菜里',
#    '有',
#    '油麦',
#    '菜',
#    '。'],
#   ['这边',
#    '向',
#    '您',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '虽然',
#    '价格比',
#    '您',
#    '期望值',
#    '高',
#    '了',
#    '一点',
#    '，',
#    '但是',
#    '味道',
#    '真的',
#    '是',
#    '很',
#    '好',
#    '的',
#    '。'],
#   ['都',
#    '没有',
#    '，',
#    '但',
#    '我',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '更',
#    '低',
#    '，',
#    '为',
#    '171',
#    '元',
#    '。'],
#   ['推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '有',
#    '精品',
#    '烤鸭',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '。'],
#   ['为',
#    '你',
#    '推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '。'],
#   ['没有',
#    '啊',
#    '，',
#    '这',
#    '两',
#    '几点',
#    '的',
#    '消费',
#    '都',
#    '比较',
#    '高',
#    '，',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '消费',
#    '稍微',
#    '低',
#    '一点',
#    '，',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['当然',
#    '可以',
#    '，',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '就',
#    '不错',
#    '，',
#    '但',
#    '人均',
#    '消费',
#    '要',
#    '171',
#    '元',
#    '。'],
#   ['按',
#    '您',
#    '的',
#    '推荐',
#    '菜',
#    '查询',
#    '，',
#    '只有',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '符合',
#    '您',
#    '的',
#    '要求',
#    '，',
#    '但',
#    '它',
#    '的',
#    '评分',
#    '是',
#    '4',
#    '分',
#    '，',
#    '然后',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['推荐',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '。'],
#   ['建议您',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '品尝',
#    '一下',
#    '，',
#    '这家',
#    '店',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。',
#    '这家',
#    '餐馆',
#    '有',
#    '很多',
#    '特色',
#    '北京小吃',
#    '，',
#    '能',
#    '让',
#    '您',
#    '一站',
#    '就',
#    '吃',
#    '个',
#    '遍',
#    '！'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '有',
#    '您',
#    '要',
#    '吃',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '只',
#    '需要',
#    '171',
#    '元',
#    '。'],
#   ['松子', '日本料理', '(', '亮马桥', '店', ')', '，', '人均', '消费', '在', '171', '元', '。'],
#   ['推荐',
#    '你',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '消费',
#    '没有',
#    '那么',
#    '高',
#    '，',
#    '人均',
#    '才',
#    '171',
#    '元',
#    '，',
#    '味道',
#    '不错',
#    '。'],
#   ['它',
#    '周边',
#    '无',
#    '餐馆',
#    '，',
#    '如果',
#    '您',
#    '以',
#    '菜品',
#    '为主',
#    '的话',
#    '，',
#    '我',
#    '推荐',
#    '您',
#    '别的',
#    '地方',
#    '的',
#    '餐馆',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '怎么样',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['你',
#    '看',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '可以',
#    '吗',
#    '？',
#    '有',
#    '蘑菇',
#    '包',
#    '和',
#    '牛排',
#    '，',
#    '就是',
#    '价格',
#    '稍稍',
#    '贵',
#    '了',
#    '一点',
#    '，',
#    '171',
#    '元',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '不错',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '。'],
#   ['没有',
#    '消费',
#    '这么',
#    '高',
#    '的',
#    '餐馆',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '才',
#    '171',
#    '元',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '不错',
#    '，',
#    '好吃',
#    '还',
#    '便宜',
#    '，',
#    '人均',
#    '171',
#    '元',
#    '。'],
#   ['在',
#    '我',
#    '的',
#    '查询',
#    '后',
#    '，',
#    '松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '这家',
#    '店有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '泡',
#    '菜汤',
#    '，',
#    '但是',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '171',
#    '元',
#    '，',
#    '低于',
#    '您',
#    '的',
#    '人均',
#    '消费',
#    '水准',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '就',
#    '不错',
#    '，',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '。'],
#   ['松子',
#    '日本料理',
#    '(',
#    '亮马桥',
#    '店',
#    ')',
#    '人均',
#    '消费',
#    '171',
#    '元',
#    '，',
#    '您',
#    '可以',
#    '去',
#    '试试',
#    '呢',
#    '。']],
#  [['为',
#    '您',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '有',
#    '您',
#    '想',
#    '吃',
#    '的',
#    '美食街',
#    '哦',
#    '。'],
#   ['推荐',
#    '您',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['我',
#    '推荐',
#    '你',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '尝尝',
#    '，',
#    '他家',
#    '做',
#    '的',
#    '很',
#    '好吃',
#    '，',
#    '不过',
#    '就是',
#    '价格',
#    '有点',
#    '高',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '，',
#    '你',
#    '能',
#    '接受',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['没有',
#    '人均',
#    '这么',
#    '高',
#    '的',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '人均',
#    '只有',
#    '67',
#    '元',
#    '。'],
#   ['吃',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '的',
#    '餐馆',
#    '没有',
#    '那么',
#    '贵',
#    '的',
#    '哟',
#    '，',
#    '推荐',
#    '你',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '价格',
#    '才',
#    '67',
#    '元',
#    '，',
#    '而且',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '做',
#    '的',
#    '也',
#    '非常',
#    '好吃',
#    '。'],
#   ['只为',
#    '您',
#    '找到',
#    '一家',
#    '店',
#    '是',
#    '\t',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['我',
#    '只查',
#    '到',
#    '一家',
#    '，',
#    'Berry',
#    ' ',
#    'Beans',
#    '可以',
#    '做',
#    '，',
#    '但',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '，',
#    '你',
#    '还要',
#    '不要',
#    '去',
#    '吃',
#    '呢',
#    '？'],
#   ['那',
#    '我',
#    '推荐',
#    '您',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '此',
#    '餐馆',
#    '正好',
#    '有',
#    '您',
#    '要',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '比',
#    '您',
#    '要求',
#    '的',
#    '标准',
#    '能',
#    '高',
#    '一点',
#    '，',
#    '但',
#    '我',
#    '觉得',
#    '此',
#    '价位',
#    '应该',
#    '能',
#    '接受',
#    '。'],
#   ['为',
#    '您',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '暂无',
#    '评分',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['Berry',
#    ' ',
#    'Beans',
#    '里面',
#    '有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '特色菜',
#    '哦',
#    '！',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '！'],
#   ['Berry', ' ', 'Beans', '挺好吃', '的', '，', '人均', '消费', '67', '元', '。'],
#   ['餐馆',
#    '周边',
#    '可',
#    '没有',
#    '这么',
#    '高价位',
#    '的',
#    '地方',
#    '，',
#    '人均',
#    '消费',
#    '最贵',
#    '的',
#    '当属',
#    'Berry',
#    ' ',
#    'Beans',
#    '了',
#    '，',
#    '也',
#    '才',
#    '不过',
#    '67',
#    '元',
#    '，',
#    '看',
#    '你',
#    '能',
#    '接受',
#    '不',
#    '？'],
#   ['很',
#    '抱歉',
#    '，',
#    '有',
#    '这些',
#    '推荐',
#    '菜',
#    '的',
#    '餐馆',
#    '我',
#    '只查',
#    '到',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '但',
#    '这里',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '没有',
#    '评分',
#    '，',
#    '你',
#    '还',
#    '会',
#    '考虑',
#    '吗',
#    '？'],
#   ['抱歉',
#    '，',
#    '没有',
#    '这样',
#    '的',
#    '餐馆',
#    '。',
#    '给',
#    '您',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['Berry', ' ', 'Beans', '很', '不错', '呢', '！', '人均', '消费', '是', '67', '元', '。'],
#   ['Berry',
#    ' ',
#    'Beans',
#    '您',
#    '可以',
#    '考虑',
#    '下',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['没关系',
#    '，',
#    'Berry',
#    ' ',
#    'Beans',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '，',
#    '还是',
#    '比较',
#    '符合',
#    '你',
#    '要求',
#    '的',
#    '。'],
#   ['建议',
#    '你们',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['那',
#    '就',
#    '推荐',
#    '您',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['亲',
#    '，',
#    '要',
#    '不',
#    '您',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '吧',
#    '，',
#    '但是',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '，',
#    '您',
#    '看',
#    '怎么样',
#    '？'],
#   ['没有',
#    '合适',
#    '的',
#    '哦',
#    '，',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '有',
#    '蛋炒饭',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['我查',
#    '了',
#    '一家',
#    'Berry',
#    ' ',
#    'Beans',
#    '的',
#    '，',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '，',
#    '你',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '推荐',
#    '菜里',
#    '有',
#    '油麦',
#    '菜',
#    '。'],
#   ['这边',
#    '向',
#    '您',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '虽然',
#    '价格比',
#    '您',
#    '期望值',
#    '高',
#    '了',
#    '一点',
#    '，',
#    '但是',
#    '味道',
#    '真的',
#    '是',
#    '很',
#    '好',
#    '的',
#    '。'],
#   ['都',
#    '没有',
#    '，',
#    '但',
#    '我',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '更',
#    '低',
#    '，',
#    '为',
#    '67',
#    '元',
#    '。'],
#   ['推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '有',
#    '精品',
#    '烤鸭',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '。'],
#   ['为',
#    '你',
#    '推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '评分',
#    '5',
#    '分',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '。'],
#   ['没有',
#    '啊',
#    '，',
#    '这',
#    '两',
#    '几点',
#    '的',
#    '消费',
#    '都',
#    '比较',
#    '高',
#    '，',
#    'Berry',
#    ' ',
#    'Beans',
#    '消费',
#    '稍微',
#    '低',
#    '一点',
#    '，',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['当然',
#    '可以',
#    '，',
#    'Berry',
#    ' ',
#    'Beans',
#    '就',
#    '不错',
#    '，',
#    '但',
#    '人均',
#    '消费',
#    '要',
#    '67',
#    '元',
#    '。'],
#   ['按',
#    '您',
#    '的',
#    '推荐',
#    '菜',
#    '查询',
#    '，',
#    '只有',
#    'Berry',
#    ' ',
#    'Beans',
#    '符合',
#    '您',
#    '的',
#    '要求',
#    '，',
#    '但',
#    '它',
#    '的',
#    '评分',
#    '是',
#    '4',
#    '分',
#    '，',
#    '然后',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['推荐',
#    'Berry',
#    ' ',
#    'Beans',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '评分',
#    '是',
#    '5',
#    '分',
#    '。'],
#   ['建议您',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '品尝',
#    '一下',
#    '，',
#    '这家',
#    '店',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。',
#    '这家',
#    '餐馆',
#    '有',
#    '很多',
#    '特色',
#    '北京小吃',
#    '，',
#    '能',
#    '让',
#    '您',
#    '一站',
#    '就',
#    '吃',
#    '个',
#    '遍',
#    '！'],
#   ['Berry',
#    ' ',
#    'Beans',
#    '有',
#    '您',
#    '要',
#    '吃',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '只',
#    '需要',
#    '67',
#    '元',
#    '。'],
#   ['Berry', ' ', 'Beans', '，', '人均', '消费', '在', '67', '元', '。'],
#   ['推荐',
#    '你',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '消费',
#    '没有',
#    '那么',
#    '高',
#    '，',
#    '人均',
#    '才',
#    '67',
#    '元',
#    '，',
#    '味道',
#    '不错',
#    '。'],
#   ['它',
#    '周边',
#    '无',
#    '餐馆',
#    '，',
#    '如果',
#    '您',
#    '以',
#    '菜品',
#    '为主',
#    '的话',
#    '，',
#    '我',
#    '推荐',
#    '您',
#    '别的',
#    '地方',
#    '的',
#    '餐馆',
#    'Berry',
#    ' ',
#    'Beans',
#    '，',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '。'],
#   ['Berry', ' ', 'Beans', '怎么样', '，', '人均', '消费', '是', '67', '元', '。'],
#   ['你',
#    '看',
#    'Berry',
#    ' ',
#    'Beans',
#    '可以',
#    '吗',
#    '？',
#    '有',
#    '蘑菇',
#    '包',
#    '和',
#    '牛排',
#    '，',
#    '就是',
#    '价格',
#    '稍稍',
#    '贵',
#    '了',
#    '一点',
#    '，',
#    '67',
#    '元',
#    '。'],
#   ['Berry', ' ', 'Beans', '不错', '，', '人均', '消费', '是', '67', '元', '。'],
#   ['没有',
#    '消费',
#    '这么',
#    '高',
#    '的',
#    '餐馆',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    'Berry',
#    ' ',
#    'Beans',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '才',
#    '67',
#    '元',
#    '。'],
#   ['Berry',
#    ' ',
#    'Beans',
#    '不错',
#    '，',
#    '好吃',
#    '还',
#    '便宜',
#    '，',
#    '人均',
#    '67',
#    '元',
#    '。'],
#   ['在',
#    '我',
#    '的',
#    '查询',
#    '后',
#    '，',
#    'Berry',
#    ' ',
#    'Beans',
#    '这家',
#    '店有',
#    '你',
#    '想',
#    '吃',
#    '的',
#    '泡',
#    '菜汤',
#    '，',
#    '但是',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '67',
#    '元',
#    '，',
#    '低于',
#    '您',
#    '的',
#    '人均',
#    '消费',
#    '水准',
#    '。'],
#   ['Berry', ' ', 'Beans', '就', '不错', '，', '人均', '消费', '67', '元', '。'],
#   ['Berry',
#    ' ',
#    'Beans',
#    '人均',
#    '消费',
#    '67',
#    '元',
#    '，',
#    '您',
#    '可以',
#    '去',
#    '试试',
#    '呢',
#    '。']],
#  [['为',
#    '您',
#    '推荐',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '人均',
#    '消费',
#    '57',
#    '元',
#    '，',
#    '有',
#    '您',
#    '想',
#    '吃',
#    '的',
#    '美食街',
#    '哦',
#    '。'],
#   ['推荐',
#    '您',
#    '去',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '57',
#    '元',
#    '。'],
#   ['我',
#    '推荐',
#    '你',
#    '去',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '尝尝',
#    '，',
#    '他家',
#    '做',
#    '的',
#    '很',
#    '好吃',
#    '，',
#    '不过',
#    '就是',
#    '价格',
#    '有点',
#    '高',
#    '，',
#    '人均',
#    '消费',
#    '是',
#    '57',
#    '元',
#    '，',
#    '你',
#    '能',
#    '接受',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '人均',
#    '消费',
#    '57',
#    '元',
#    '，',
#    '您',
#    '看',
#    '可以',
#    '吗',
#    '？'],
#   ['为',
#    '您',
#    '推荐',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '吧',
#    '，',
#    '人均',
#    '消费',
#    '57',
#    '元',
#    '，',
#    '可以',
#    '吗',
#    '？'],
#   ['没有',
#    '人均',
#    '这么',
#    '高',
#    '的',
#    '，',
#    '推荐',
#    '您',
#    '去',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '人均',
#    '只有',
#    '57',
#    '元',
#    '。'],
#   ['吃',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '的',
#    '餐馆',
#    '没有',
#    '那么',
#    '贵',
#    '的',
#    '哟',
#    '，',
#    '推荐',
#    '你',
#    '去',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '价格',
#    '才',
#    '57',
#    '元',
#    '，',
#    '而且',
#    '干锅',
#    '千叶',
#    '豆腐',
#    '做',
#    '的',
#    '也',
#    '非常',
#    '好吃',
#    '。'],
#   ['只为',
#    '您',
#    '找到',
#    '一家',
#    '店',
#    '是',
#    '\t',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '但是',
#    '它家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '57',
#    '元',
#    '。'],
#   ['我',
#    '只查',
#    '到',
#    '一家',
#    '，',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '可以',
#    '做',
#    '，',
#    '但',
#    '他家',
#    '的',
#    '人均',
#    '消费',
#    '是',
#    '57',
#    '元',
#    '，',
#    '你',
#    '还要',
#    '不要',
#    '去',
#    '吃',
#    '呢',
#    '？'],
#   ['那',
#    '我',
#    '推荐',
#    '您',
#    '东兴',
#    '顺',
#    '爆肚',
#    '张',
#    '，',
#    '此',
#    '餐馆',
#    '正好',
#    '有',
#    '您',
#    '要',
#    '的',
#    '菜品',
#    '，',
#    '但',
#    '它',
#    '的',
#    '人均',
#    '消费',
#    '57',
#    '元',
# ...
#    '到',
#    '几点',
#    '啊',
#    '？',
#    '我怕',
#    '去',
#    '的',
#    '太晚',
#    '餐厅',
#    '闭店',
#    '了',
#    '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我俩',
#    '也',
#    '看看',
#    '自己',
#    '是否',
#    '有',
#    '空余',
#    '时间',
#    '。']],
#  [['营业时间', '是', '什么', '时间', '？'],
#   ['是', '吗', '，', '那', '这家', '店', '的', '营业时间', '你', '知道', '吗', '？'],
#   ['可以',
#    '接受',
#    '，',
#    '想',
#    '吃',
#    '好吃',
#    '的',
#    '，',
#    '就',
#    '得',
#    '舍得',
#    '花钱',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['嗯', '呢', '。', '还有', '这家', '餐馆', '的', '营业时间', '是', '怎样', '的', '？'],
#   ['嗯', '呢', '。', '还有', '这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['收到', '，', '那', '你', '知道', '这个', '餐馆', '的', '营业时间', '吗', '？'],
#   ['那好',
#    '吧',
#    '，',
#    '就',
#    '去',
#    '这里',
#    '吧',
#    '，',
#    '帮',
#    '我查',
#    '一下',
#    '这里',
#    '的',
#    '营业时间',
#    '吧',
#    '。'],
#   ['嗯', '呢', '。', '这家', '餐馆', '的', '营业时间', '是', '咋样', '的', '？'],
#   ['是',
#    '吗',
#    '，',
#    '那',
#    '我',
#    '就',
#    '去',
#    '这里',
#    '吃',
#    '吧',
#    '，',
#    '它家',
#    '几点',
#    '营业',
#    '呀',
#    '？'],
#   ['好', '呀', '，', '那', '你', '帮', '我查', '一下', '它家', '的', '营业时间', '吧', '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我',
#    '和',
#    '对象',
#    '安排',
#    '下',
#    '时间',
#    '。'],
#   ['好', '。', '这家', '餐馆', '的', '营业时间', '是', '咋样', '的', '啊', '？'],
#   ['还行', '不贵', '，', '它家', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['营业时间', '呢', '？'],
#   ['喜欢',
#    '呀',
#    '，',
#    '它家',
#    '营业时间',
#    '是',
#    '什么',
#    '时候',
#    '啊',
#    '，',
#    '我',
#    '都',
#    '迫不及待',
#    '了',
#    '。'],
#   ['太',
#    '完美',
#    '了',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我们',
#    '好',
#    '安排',
#    '好',
#    '我们',
#    '的',
#    '行程',
#    '。'],
#   ['请问', '这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['那', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['这个', '餐馆', '的', '营业时间', '是', '？'],
#   ['好', '呀', '，', '那', '它', '家', '营业时间', '是', '什么', '时候', '呀', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['是', '呢', '，', '一点', '都', '不贵', '，', '他家', '都', '什么', '时间', '营业', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['哦', '，', '那', '它', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['哦', '，', '那', '你', '知道', '他家', '的', '电话', '吗', '？'],
#   ['行',
#    '，',
#    '这样',
#    '我',
#    '就',
#    '方便',
#    '联系',
#    '了',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '都',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['也',
#    '行',
#    '，',
#    '营业时间',
#    '能',
#    '告诉',
#    '我下',
#    '吗',
#    '？',
#    '我',
#    '得',
#    '知道',
#    '什么',
#    '时候',
#    '去',
#    '合适',
#    '啊',
#    '。'],
#   ['真是',
#    '太好了',
#    '，',
#    '就',
#    '去',
#    '它',
#    '家',
#    '吃',
#    '了',
#    '，',
#    '能',
#    '告诉',
#    '我',
#    '一下',
#    '它家',
#    '的',
#    '营业时间',
#    '吗',
#    '？'],
#   ['还', '不错', '，', '知道', '它家', '营业时间', '吗', '？'],
#   ['景点', '好多', '呀', '，', '那', '这个', '餐馆', '一般', '几点', '营业', '呀', '？'],
#   ['是',
#    '吗',
#    '，',
#    '那',
#    '我',
#    '可得',
#    '过去',
#    '尝尝',
#    '，',
#    '它家',
#    '一般',
#    '都',
#    '什么',
#    '时间',
#    '营业',
#    '呀',
#    '？'],
#   ['好', '啊', '，', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['行', '啊', '，', '它家', '营业时间', '是', '几点', '啊', '？'],
#   ['听',
#    '着',
#    '就',
#    '够',
#    '场面',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '都',
#    '是',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['这家', '店', '的', '营业时间', '是', '几点', '到', '几点', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['好', '啊', '，', '你', '知道', '它家', '的', '营业时间', '吗', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '?'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['请问', '餐馆', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['我', '想要', '知道', '这个', '餐馆', '的', '营业时间', '。'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['那', '您', '和', '我', '说', '一下', '这家', '餐厅', '的', '营业时间', '吧', '。'],
#   ['可以', '的', '，', '他家', '什么', '时间', '营业', '？'],
#   ['他家', '什么', '时间', '营业', '？'],
#   ['是', '吗', '，', '那', '你', '知道', '它家', '的', '营业时间', '吗', '？'],
#   ['营业时间', '是', '什么', '时候', '？'],
#   ['这', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['营业时间', '是', '？'],
#   ['这下',
#    '我',
#    '心里',
#    '就',
#    '有',
#    '底',
#    '了',
#    '，',
#    '你',
#    '知道',
#    '这家',
#    '餐馆',
#    '的',
#    '是',
#    '营业',
#    '到',
#    '几点',
#    '吗',
#    '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['那',
#    '他',
#    '的',
#    ' ',
#    '营业时间',
#    '是',
#    '几点',
#    '到',
#    '几点',
#    '啊',
#    '？',
#    '我怕',
#    '去',
#    '的',
#    '太晚',
#    '餐厅',
#    '闭店',
#    '了',
#    '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我俩',
#    '也',
#    '看看',
#    '自己',
#    '是否',
#    '有',
#    '空余',
#    '时间',
#    '。']],
#  [['营业时间', '是', '什么', '时间', '？'],
#   ['是', '吗', '，', '那', '这家', '店', '的', '营业时间', '你', '知道', '吗', '？'],
#   ['可以',
#    '接受',
#    '，',
#    '想',
#    '吃',
#    '好吃',
#    '的',
#    '，',
#    '就',
#    '得',
#    '舍得',
#    '花钱',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['嗯', '呢', '。', '还有', '这家', '餐馆', '的', '营业时间', '是', '怎样', '的', '？'],
#   ['嗯', '呢', '。', '还有', '这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['收到', '，', '那', '你', '知道', '这个', '餐馆', '的', '营业时间', '吗', '？'],
#   ['那好',
#    '吧',
#    '，',
#    '就',
#    '去',
#    '这里',
#    '吧',
#    '，',
#    '帮',
#    '我查',
#    '一下',
#    '这里',
#    '的',
#    '营业时间',
#    '吧',
#    '。'],
#   ['嗯', '呢', '。', '这家', '餐馆', '的', '营业时间', '是', '咋样', '的', '？'],
#   ['是',
#    '吗',
#    '，',
#    '那',
#    '我',
#    '就',
#    '去',
#    '这里',
#    '吃',
#    '吧',
#    '，',
#    '它家',
#    '几点',
#    '营业',
#    '呀',
#    '？'],
#   ['好', '呀', '，', '那', '你', '帮', '我查', '一下', '它家', '的', '营业时间', '吧', '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我',
#    '和',
#    '对象',
#    '安排',
#    '下',
#    '时间',
#    '。'],
#   ['好', '。', '这家', '餐馆', '的', '营业时间', '是', '咋样', '的', '啊', '？'],
#   ['还行', '不贵', '，', '它家', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['营业时间', '呢', '？'],
#   ['喜欢',
#    '呀',
#    '，',
#    '它家',
#    '营业时间',
#    '是',
#    '什么',
#    '时候',
#    '啊',
#    '，',
#    '我',
#    '都',
#    '迫不及待',
#    '了',
#    '。'],
#   ['太',
#    '完美',
#    '了',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我们',
#    '好',
#    '安排',
#    '好',
#    '我们',
#    '的',
#    '行程',
#    '。'],
#   ['请问', '这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['那', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['这个', '餐馆', '的', '营业时间', '是', '？'],
#   ['好', '呀', '，', '那', '它', '家', '营业时间', '是', '什么', '时候', '呀', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['是', '呢', '，', '一点', '都', '不贵', '，', '他家', '都', '什么', '时间', '营业', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['哦', '，', '那', '它', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['哦', '，', '那', '你', '知道', '他家', '的', '电话', '吗', '？'],
#   ['行',
#    '，',
#    '这样',
#    '我',
#    '就',
#    '方便',
#    '联系',
#    '了',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '都',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['也',
#    '行',
#    '，',
#    '营业时间',
#    '能',
#    '告诉',
#    '我下',
#    '吗',
#    '？',
#    '我',
#    '得',
#    '知道',
#    '什么',
#    '时候',
#    '去',
#    '合适',
#    '啊',
#    '。'],
#   ['真是',
#    '太好了',
#    '，',
#    '就',
#    '去',
#    '它',
#    '家',
#    '吃',
#    '了',
#    '，',
#    '能',
#    '告诉',
#    '我',
#    '一下',
#    '它家',
#    '的',
#    '营业时间',
#    '吗',
#    '？'],
#   ['还', '不错', '，', '知道', '它家', '营业时间', '吗', '？'],
#   ['景点', '好多', '呀', '，', '那', '这个', '餐馆', '一般', '几点', '营业', '呀', '？'],
#   ['是',
#    '吗',
#    '，',
#    '那',
#    '我',
#    '可得',
#    '过去',
#    '尝尝',
#    '，',
#    '它家',
#    '一般',
#    '都',
#    '什么',
#    '时间',
#    '营业',
#    '呀',
#    '？'],
#   ['好', '啊', '，', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['行', '啊', '，', '它家', '营业时间', '是', '几点', '啊', '？'],
#   ['听',
#    '着',
#    '就',
#    '够',
#    '场面',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '都',
#    '是',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['这家', '店', '的', '营业时间', '是', '几点', '到', '几点', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['好', '啊', '，', '你', '知道', '它家', '的', '营业时间', '吗', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '?'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['请问', '餐馆', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['我', '想要', '知道', '这个', '餐馆', '的', '营业时间', '。'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['那', '您', '和', '我', '说', '一下', '这家', '餐厅', '的', '营业时间', '吧', '。'],
#   ['可以', '的', '，', '他家', '什么', '时间', '营业', '？'],
#   ['他家', '什么', '时间', '营业', '？'],
#   ['是', '吗', '，', '那', '你', '知道', '它家', '的', '营业时间', '吗', '？'],
#   ['营业时间', '是', '什么', '时候', '？'],
#   ['这', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['营业时间', '是', '？'],
#   ['这下',
#    '我',
#    '心里',
#    '就',
#    '有',
#    '底',
#    '了',
#    '，',
#    '你',
#    '知道',
#    '这家',
#    '餐馆',
#    '的',
#    '是',
#    '营业',
#    '到',
#    '几点',
#    '吗',
#    '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['那',
#    '他',
#    '的',
#    ' ',
#    '营业时间',
#    '是',
#    '几点',
#    '到',
#    '几点',
#    '啊',
#    '？',
#    '我怕',
#    '去',
#    '的',
#    '太晚',
#    '餐厅',
#    '闭店',
#    '了',
#    '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我俩',
#    '也',
#    '看看',
#    '自己',
#    '是否',
#    '有',
#    '空余',
#    '时间',
#    '。']],
#  [['营业时间', '是', '什么', '时间', '？'],
#   ['是', '吗', '，', '那', '这家', '店', '的', '营业时间', '你', '知道', '吗', '？'],
#   ['可以',
#    '接受',
#    '，',
#    '想',
#    '吃',
#    '好吃',
#    '的',
#    '，',
#    '就',
#    '得',
#    '舍得',
#    '花钱',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['嗯', '呢', '。', '还有', '这家', '餐馆', '的', '营业时间', '是', '怎样', '的', '？'],
#   ['嗯', '呢', '。', '还有', '这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['收到', '，', '那', '你', '知道', '这个', '餐馆', '的', '营业时间', '吗', '？'],
#   ['那好',
#    '吧',
#    '，',
#    '就',
#    '去',
#    '这里',
#    '吧',
#    '，',
#    '帮',
#    '我查',
#    '一下',
#    '这里',
#    '的',
#    '营业时间',
#    '吧',
#    '。'],
#   ['嗯', '呢', '。', '这家', '餐馆', '的', '营业时间', '是', '咋样', '的', '？'],
#   ['是',
#    '吗',
#    '，',
#    '那',
#    '我',
#    '就',
#    '去',
#    '这里',
#    '吃',
#    '吧',
#    '，',
#    '它家',
#    '几点',
#    '营业',
#    '呀',
#    '？'],
#   ['好', '呀', '，', '那', '你', '帮', '我查', '一下', '它家', '的', '营业时间', '吧', '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我',
#    '和',
#    '对象',
#    '安排',
#    '下',
#    '时间',
#    '。'],
#   ['好', '。', '这家', '餐馆', '的', '营业时间', '是', '咋样', '的', '啊', '？'],
#   ['还行', '不贵', '，', '它家', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['营业时间', '呢', '？'],
#   ['喜欢',
#    '呀',
#    '，',
#    '它家',
#    '营业时间',
#    '是',
#    '什么',
#    '时候',
#    '啊',
#    '，',
#    '我',
#    '都',
#    '迫不及待',
#    '了',
#    '。'],
#   ['太',
#    '完美',
#    '了',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我们',
#    '好',
#    '安排',
#    '好',
#    '我们',
#    '的',
#    '行程',
#    '。'],
#   ['请问', '这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['那', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['这个', '餐馆', '的', '营业时间', '是', '？'],
#   ['好', '呀', '，', '那', '它', '家', '营业时间', '是', '什么', '时候', '呀', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['是', '呢', '，', '一点', '都', '不贵', '，', '他家', '都', '什么', '时间', '营业', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['哦', '，', '那', '它', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['哦', '，', '那', '你', '知道', '他家', '的', '电话', '吗', '？'],
#   ['行',
#    '，',
#    '这样',
#    '我',
#    '就',
#    '方便',
#    '联系',
#    '了',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '都',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['也',
#    '行',
#    '，',
#    '营业时间',
#    '能',
#    '告诉',
#    '我下',
#    '吗',
#    '？',
#    '我',
#    '得',
#    '知道',
#    '什么',
#    '时候',
#    '去',
#    '合适',
#    '啊',
#    '。'],
#   ['真是',
#    '太好了',
#    '，',
#    '就',
#    '去',
#    '它',
#    '家',
#    '吃',
#    '了',
#    '，',
#    '能',
#    '告诉',
#    '我',
#    '一下',
#    '它家',
#    '的',
#    '营业时间',
#    '吗',
#    '？'],
#   ['还', '不错', '，', '知道', '它家', '营业时间', '吗', '？'],
#   ['景点', '好多', '呀', '，', '那', '这个', '餐馆', '一般', '几点', '营业', '呀', '？'],
#   ['是',
#    '吗',
#    '，',
#    '那',
#    '我',
#    '可得',
#    '过去',
#    '尝尝',
#    '，',
#    '它家',
#    '一般',
#    '都',
#    '什么',
#    '时间',
#    '营业',
#    '呀',
#    '？'],
#   ['好', '啊', '，', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['行', '啊', '，', '它家', '营业时间', '是', '几点', '啊', '？'],
#   ['听',
#    '着',
#    '就',
#    '够',
#    '场面',
#    '，',
#    '你',
#    '知道',
#    '他家',
#    '都',
#    '是',
#    '几点',
#    '营业',
#    '吗',
#    '？'],
#   ['这家', '店', '的', '营业时间', '是', '几点', '到', '几点', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['好', '啊', '，', '你', '知道', '它家', '的', '营业时间', '吗', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '?'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['餐馆', '的', '营业时间', '是', '？'],
#   ['请问', '餐馆', '的', '营业时间', '是', '什么', '时候', '？'],
#   ['我', '想要', '知道', '这个', '餐馆', '的', '营业时间', '。'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['那', '您', '和', '我', '说', '一下', '这家', '餐厅', '的', '营业时间', '吧', '。'],
#   ['可以', '的', '，', '他家', '什么', '时间', '营业', '？'],
#   ['他家', '什么', '时间', '营业', '？'],
#   ['是', '吗', '，', '那', '你', '知道', '它家', '的', '营业时间', '吗', '？'],
#   ['营业时间', '是', '什么', '时候', '？'],
#   ['这', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['营业时间', '是', '？'],
#   ['这下',
#    '我',
#    '心里',
#    '就',
#    '有',
#    '底',
#    '了',
#    '，',
#    '你',
#    '知道',
#    '这家',
#    '餐馆',
#    '的',
#    '是',
#    '营业',
#    '到',
#    '几点',
#    '吗',
#    '？'],
#   ['这家', '餐馆', '的', '营业时间', '是', '？'],
#   ['餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#   ['那',
#    '他',
#    '的',
#    ' ',
#    '营业时间',
#    '是',
#    '几点',
#    '到',
#    '几点',
#    '啊',
#    '？',
#    '我怕',
#    '去',
#    '的',
#    '太晚',
#    '餐厅',
#    '闭店',
#    '了',
#    '。'],
#   ['嗯',
#    '嗯',
#    '，',
#    '这个',
#    '餐馆',
#    '的',
#    '营业时间',
#    '是',
#    '咋样',
#    '的',
#    '，',
#    '我俩',
#    '也',
#    '看看',
#    '自己',
#    '是否',
#    '有',
#    '空余',
#    '时间',
#    '。']]]
# gens:
# [['你好',
#   '，',
#   '帮',
#   '我',
#   '推荐',
#   '一个',
#   '人均',
#   '消费',
#   '在',
#   '50',
#   '-',
#   '100',
#   '元',
#   '之间',
#   '的',
#   '并且',
#   '有',
#   '美食街',
#   '这',
#   '道菜',
#   '的',
#   '餐馆',
#   '，',
#   '谢谢',
#   '。'],
#  ['你好',
#   '，',
#   '帮',
#   '我',
#   '推荐',
#   '一个',
#   '有',
#   '千层',
#   '肚',
#   '这',
#   '道菜',
#   '的',
#   '并且',
#   '人均',
#   '消费',
#   '在',
#   '100',
#   '-',
#   '150',
#   '元',
#   '之间',
#   '的',
#   '餐馆',
#   '，',
#   '谢谢',
#   '。'],
#  ['您好',
#   '，',
#   '我要',
#   '请客吃饭',
#   '，',
#   '推荐',
#   '一家',
#   '有糖',
#   '油饼',
#   '的',
#   '餐馆',
#   '，',
#   '人均',
#   '消费',
#   '在',
#   '50',
#   '-',
#   '100',
#   '元',
#   '，',
#   '谢谢',
#   '。'],
#  ['您好',
#   '，',
#   '我',
#   '想',
#   '找',
#   '一家人',
#   '均',
#   '消费',
#   '是',
#   '150',
#   '-',
#   '500',
#   '元',
#   '的',
#   '，',
#   '有',
#   '皮蛋',
#   '豆腐',
#   '的',
#   '餐馆',
#   '，',
#   '谢谢',
#   '。'],
#  ['你好',
#   '，',
#   '帮',
#   '我',
#   '推荐',
#   '一个',
#   '人均',
#   '消费',
#   '在',
#   '50',
#   '-',
#   '100',
#   '元',
#   '之间',
#   '的',
#   '并且',
#   '有',
#   '炒年糕',
#   '这',
#   '道菜',
#   '的',
#   '餐馆',
#   '，',
#   '谢谢',
#   '。'],
#  ['也',
#   '可以',
#   '呀',
#   '，',
#   '我',
#   '还',
#   '划算',
#   '了',
#   '呢',
#   '，',
#   '就',
#   '去',
#   '那',
#   '了',
#   '。',
#   '然后',
#   '餐馆',
#   '都',
#   '什么',
#   '时间',
#   '营业',
#   '呢',
#   '？'],
#  ['这家', '餐馆', '的', '营业时间', '是', '什么', '时候', '啊', '？'],
#  ['我', '记下', '了', '，', '能帮', '我查', '一下', '该', '餐馆', '的', '营业时间', '吗', '？'],
#  ['行',
#   '，',
#   '就是',
#   '想',
#   '找',
#   '这样',
#   '的',
#   '地方',
#   '。',
#   '这家',
#   '餐馆',
#   '的',
#   '营业时间',
#   '最晚',
#   '到',
#   '几点',
#   '？'],
#  ['好', '的', '，', '那', '它', '家', '都', '什么', '时间', '营业', '呀', '？']]
# generated_sens_usr.txt saved!
# Calculate bleu-4
# BLEU-4: 0.5346
# BLEU-4: 0.5346
# Model on 500 session 4238 sentences data_key=usr
